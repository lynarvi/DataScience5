# %%
import numpy as np

# %%
# 4.	Using NumPy create an array containing 500 random floats between 0 and 10

x = np.random.uniform(0.0,10.0,500)
print(x)
# Out:
# [9.37526429 0.42273704 5.96387153 6.43504075 6.01813133 7.89217768
#  7.15267185 5.57608656 8.19920992 1.6331684  5.22525684 6.04198821
#  1.65520499 1.70461057 5.63906051 0.02511337 3.55849139 3.97917535
#  9.80915309 1.41823229 2.89403246 5.66023648 4.89163738 9.42936118
#  0.79867851 9.43005083 1.29938651 1.32421387 0.87532471 1.72652818
#  3.79897775 1.19988233 9.80952853 1.26988777 1.73980716 5.71361606
#  0.14739611 1.68827832 5.39413164 1.10869691 9.59014716 9.08795734
#  7.03008462 2.1023775  2.00744085 6.46738649 2.18257853 5.04522229
#  0.15504357 5.47064647 4.80970257 4.61729684 7.80422551 3.89700983
#  0.22600579 3.27977302 2.83264187 0.89670652 8.35767207 7.40441996
#  9.42531394 6.76272678 1.81400659 8.59280443 4.90037648 1.82153399
#  7.60310894 7.22866386 6.07211165 3.33402153 7.83175256 4.12047606
#  4.74333708 5.17507801 6.19130927 6.38833121 5.10292866 0.37935928
#  9.44955258 6.03218179 6.66616454 2.445396   1.22629734 4.5935308
# ...

# %%
# draw a histogram with 20 bars using the generated data sets.

import matplotlib.pyplot as plt

plt.hist(x, 20)
plt.show()
